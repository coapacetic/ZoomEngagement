# %%
###  Import Libraries

# Library for importing configuration files
from configparser import ConfigParser

# Library for converting text to JSON file
import json

# Library for sending HTTP requests
import requests

# Library for converting client id and client secret to base 64
import base64

# %%
### Read in the config file with the userinfo, client_id, and client_secret

# Read config.ini file
config_object = ConfigParser()
config_object.read('ZoomCred.ini')

# Get the key information
userinfo = config_object['USERINFO']
client_id = userinfo['client_id'] 
client_secret = userinfo['client_secret']
redirect_uri = userinfo['redirect_uri']
authorization_code = userinfo['authorization_code']

# %%
### Step two of the OAuth2 process - send the code to get the token

# Define the URL for which to get the token from the OAuth2 server
url = 'https://zoom.us/oauth/token'

# Define the headers for getting the API Token
# Convert client id and client secret to base 64
auth_header = base64.b64encode(bytes(str(client_id) + ":" + str(client_secret),'utf-8'))
auth_header = auth_header.decode('ascii')
auth_header = 'Basic '+ auth_header
headers = {"Authorization": auth_header}

# Redefine the authorization code if necessary
authorization_code = 'TLWf0657xR_qrOc8lYCRBOMK-5zb1WAXQ'

# Define the payload for getting the API Token
payload = {'grant_type':'authorization_code',
           'code':authorization_code,
           'redirect_uri': redirect_uri}

# Build the URL for getting the access token
method = 'POST'
built_url = requests.Request(method, url, params = payload).prepare()
built_url = built_url.url

# Send the HTTP request to get the access token
authReply = requests.post(url, headers = headers, data = payload)

# Print the status code to verify that the request has been received | 200 is GOOD!
authReply.status_code
# Out:
# https://zoom.us/oauth/token?grant_type=authorization_code&code=TLWf0657xR_qrOc8lYCRBOMK-5zb1WAXQ&redirect_uri=http%3A%2F%2Flocalhost%2Ftest
# '{"access_token":"eyJhbGciOiJIUzUxMiIsInYiOiIyLjAiLCJraWQiOiIxYjBlZWI2ZC02N2VlLTQwNTItYmFhOS1kZWY4NDhmOWQ3NDQifQ.....Wg9JB3HyRB6emZlB2_p-u-2SiRCX9kMyhwL9N9B_QO0xFiCGufq-k7gF3HHswm4hdBBrtMJcI2kIGIvSE0-EpQ","token_type":"bearer","refresh_token":"eyJhbGciOiJIUzUxMiIsInYiOiIyLjAiLCJraWQiOiI3ZDYzMTVjNy0yNjA0LTRkZjQtODliOS05NzYwMzE3NzlkOTQifQ.....I-OzYhs-zi4ZVjHxJZYIMPSuE7hYYdBf943M_ayORUdmprWcNa8sAbnDVLjfqulx3CgBTT-rOPNDh_y7ZP9weQ","expires_in":3599,"scope":"chat_channel:read chat_channel:write chat_contact:read chat_message:read chat_message:write meeting:read meeting:write pac:read pac:write phone:read phone:write recording:read recording:write tsp:read tsp:write user:read user:write user_profile webinar:read webinar:write"}'

# %%
### Extract the access token and refresh token from the json response
token_response = authReply.json()
access_token = token_response['access_token']
refresh_token = token_response['refresh_token']
refresh_token
headers = {'Authorization': "Bearer {}".format(access_token)}

# Print the access and refresh token 
print('Access Token: {}\n'.format(access_token))
print('Refresh Token: {}\n'.format(refresh_token))
# Out:
# Access Token: eyJhbGciOiJIUzUxMiIsInYiOiIyLjAiLCJraWQiOiIxYjBlZWI2ZC02N2VlLTQwNTItYmFhOS1kZWY4NDhmOWQ3NDQifQ.....Wg9JB3HyRB6emZlB2_p-u-2SiRCX9kMyhwL9N9B_QO0xFiCGufq-k7gF3HHswm4hdBBrtMJcI2kIGIvSE0-EpQ
#
# Refresh Token: eyJhbGciOiJIUzUxMiIsInYiOiIyLjAiLCJraWQiOiI3ZDYzMTVjNy0yNjA0LTRkZjQtODliOS05NzYwMzE3NzlkOTQifQ.....I-OzYhs-zi4ZVjHxJZYIMPSuE7hYYdBf943M_ayORUdmprWcNa8sAbnDVLjfqulx3CgBTT-rOPNDh_y7ZP9weQ

# %%
### Refresh token script - the access token will expire after 1 hour - this script will refresh it!

# Define the URL for which to get the token from the OAuth2 server
url = 'https://zoom.us/oauth/token'

# Define the headers for getting the API Token
# Convert client id and client secret to base 64
auth_header = base64.b64encode(bytes(str(client_id) + ":" + str(client_secret),'utf-8'))
auth_header = auth_header.decode('ascii')
auth_header = 'Basic '+ auth_header
headers = {"Authorization": auth_header}

# Define the payload for getting the API Token
payload = {'grant_type':'refresh_token',
           'refresh_token':refresh_token}

# Build the URL for getting the access token
method = 'POST'
built_url = requests.Request(method, url, params = payload).prepare()
built_url = built_url.url
print(built_url)

# Send the HTTP request to get the access token
refresh_response = requests.post(url, headers = headers, data = payload)
refresh_response.text
# Out:
# https://zoom.us/oauth/token?grant_type=refresh_token&refresh_token=eyJhbGciOiJIUzUxMiIsInYiOiIyLjAiLCJraWQiOiJiYjgwZGFmNi0xOGIxLTQ5MDktOWQzNy02Y2QwYWVlMWYzNzkifQ.....DpigAp_uT_i5nRFu1jNxCZP5GCuf8fA7fKVDCYYbm-U7KgWrpdzXQWyB2t9AcjbwjBvDfvEMsheH2y_dqVb2Fw
# '{"reason":"Invalid Token!","error":"invalid_request"}'

# %%
### Get the list of meetings for my own account

# Establish the endpoint for getting the request from
endpoint = r"https://api.zoom.us/v2/users/me/meetings"

# Send the payload to the url to finalize the query
meetings = requests.get(url = endpoint, headers = headers)
meetings.json()
# Out:
# {'page_count': 1,
#  'page_number': 1,
#  'page_size': 30,
#  'total_records': 13,
#  'meetings': [{'uuid': 'RN5jo+TDRzWHdHLvdSQ40A==',
#    'id': 662065487,
#    'host_id': 'qrOc8lYCRBOMK-5zb1WAXQ',
#    'topic': "Coapman's BC Classroom",
#    'type': 8,
#    'start_time': '2020-04-09T12:00:00Z',
#    'duration': 60,
#    'timezone': 'America/New_York',
#    'created_at': '2020-03-16T20:18:07Z',
#    'join_url': 'https://uncommonschools.zoom.us/j/662065487'},
#   {'uuid': 'OgSfhxhcRXSDJvy77EOoOA==',
#    'id': 744697203,
#    'host_id': 'qrOc8lYCRBOMK-5zb1WAXQ',
#    'topic': 'Upper Math Check In',
#    'type': 3,
#    'start_time': '2020-03-23T13:00:00Z',
#    'duration': 15,
#    'timezone': 'America/New_York',
#    'created_at': '2020-03-23T11:56:36Z',
#    'join_url': 'https://uncommonschools.zoom.us/j/744697203'},
#   {'uuid': 'QHwew423RVqSsyHwWUD7/A==',
#    'id': 691816826,
#    'host_id': 'qrOc8lYCRBOMK-5zb1WAXQ',
#    'topic': 'Coapman Office Hours',
#    'type': 3,
#    'start_time': '2020-03-25T18:00:00Z',
#    'duration': 60,
#    'timezone': 'America/New_York',
#    'created_at': '2020-03-25T16:19:15Z',
#    'join_url': 'https://uncommonschools.zoom.us/j/691816826'},
#   {'uuid': 'PVWPDG1eRvS1627oMwNF/A==',
#    'id': 346168450,
#    'host_id': 'qrOc8lYCRBOMK-5zb1WAXQ',
#    'topic': "Mr. Coapman's Office Hours",
#    'type': 2,
#    'start_time': '2020-03-18T18:00:00Z',
#    'duration': 60,
#    'timezone': 'America/New_York',
#    'created_at': '2020-03-18T14:59:50Z',
#    'join_url': 'https://uncommonschools.zoom.us/j/346168450'},
#   {'uuid': 'W4mhNP6uQhm5kPFojQVgvg==',
#    'id': 763642030,
#    'host_id': 'qrOc8lYCRBOMK-5zb1WAXQ',
#    'topic': "Mr. Coapman's Office Hours",
#    'type': 2,
#    'start_time': '2020-03-19T18:30:00Z',
#    'duration': 30,
#    'timezone': 'America/New_York',
#    'created_at': '2020-03-19T14:55:31Z',
#    'join_url': 'https://uncommonschools.zoom.us/j/763642030'},
#   {'uuid': 'UEi1Zby9T/KTYG+gCSTcKA==',
#    'id': 189832847,
#    'host_id': 'qrOc8lYCRBOMK-5zb1WAXQ',
#    'topic': 'EA/KC Check In',
#    'type': 2,
#    'start_time': '2020-03-20T17:00:00Z',
#    'duration': 30,
#    'timezone': 'America/New_York',
#    'created_at': '2020-03-20T13:54:08Z',
#    'join_url': 'https://uncommonschools.zoom.us/j/189832847'},
#   {'uuid': '6KLg2YfQRtuBydH/Gr09qw==',
#    'id': 526254265,
#    'host_id': 'qrOc8lYCRBOMK-5zb1WAXQ',
#    'topic': 'quiplash!!',
#    'type': 2,
#    'start_time': '2020-03-21T00:00:00Z',
#    'duration': 90,
#    'timezone': 'America/New_York',
#    'created_at': '2020-03-20T22:05:32Z',
#    'join_url': 'https://uncommonschools.zoom.us/j/526254265'},
#   {'uuid': 'akdI/HavQCGdO6KjYqb2rQ==',
#    'id': 872117473,
#    'host_id': 'qrOc8lYCRBOMK-5zb1WAXQ',
#    'topic': 'Math Leadership Checkin',
#    'type': 2,
#    'start_time': '2020-03-24T17:00:00Z',
#    'duration': 15,
#    'timezone': 'America/New_York',
#    'created_at': '2020-03-24T15:02:40Z',
#    'join_url': 'https://uncommonschools.zoom.us/j/872117473'},
#   {'uuid': 'U2GgAxEgT6a/dPlxgtksDg==',
#    'id': 661347403,
#    'host_id': 'qrOc8lYCRBOMK-5zb1WAXQ',
#    'topic': 'Math Department Check In',
#    'type': 2,
#    'start_time': '2020-03-24T19:15:00Z',
#    'duration': 15,
#    'timezone': 'America/New_York',
#    'created_at': '2020-03-24T15:03:29Z',
#    'join_url': 'https://uncommonschools.zoom.us/j/661347403'},
#   {'uuid': 'DCXR9WGjS5+a1+XMDAgtpQ==',
#    'id': 252758413,
#    'host_id': 'qrOc8lYCRBOMK-5zb1WAXQ',
#    'topic': 'Math Dept. Meeting TEST',
#    'type': 2,
#    'start_time': '2020-03-26T15:30:00Z',
#    'duration': 30,
#    'timezone': 'America/New_York',
#    'created_at': '2020-03-26T14:54:28Z',
#    'join_url': 'https://uncommonschools.zoom.us/j/252758413'},
#   {'uuid': 'd7JmpwcYSnK5cZ3s5L98QQ==',
#    'id': 321122542,
#    'host_id': 'qrOc8lYCRBOMK-5zb1WAXQ',
#    'topic': 'Sherry NYC',
#    'type': 2,
#    'start_time': '2020-03-26T23:30:00Z',
#    'duration': 60,
#    'timezone': 'America/New_York',
#    'created_at': '2020-03-26T14:16:28Z',
#    'join_url': 'https://uncommonschools.zoom.us/j/321122542'},
#   {'uuid': 'QxzitTcVQiC0so07AlGRmg==',
#    'id': 791064592,
#    'host_id': 'qrOc8lYCRBOMK-5zb1WAXQ',
#    'topic': 'Coapman!!',
#    'type': 2,
#    'start_time': '2020-04-05T00:00:00Z',
#    'duration': 30,
#    'timezone': 'America/New_York',
#    'created_at': '2020-04-04T23:30:19Z',
#    'join_url': 'https://uncommonschools.zoom.us/j/791064592?pwd=elBVOE5YNktyZVVUQXM2Nk1IRWVDdz09'},
#   {'uuid': '3zxaOpkOSAGrn+sU5sxMHQ==',
#    'id': 230722003,
#    'host_id': 'qrOc8lYCRBOMK-5zb1WAXQ',
#    'topic': 'Settle Catan!',
#    'type': 2,
#    'start_time': '2020-04-06T00:00:00Z',
#    'duration': 120,
#    'timezone': 'America/New_York',
#    'created_at': '2020-04-05T23:59:10Z',
#    'join_url': 'https://uncommonschools.zoom.us/j/230722003'}]}

# %%
### Get the participant list from a previous meeting based on meeting ID number
meetingUUID = '662065487'

# Establish the endpoint for getting the request from
endpoint = r"https://api.zoom.us/v2/past_meetings/{}/participants".format(meetingUUID)
print(endpoint)
# Send the payload to the url to finalize the query
participants = requests.get(url = endpoint, headers = headers)
participants.json()
# Out:
# https://api.zoom.us/v2/past_meetings/662065487/participants
# {'page_count': 3,
#  'page_size': 30,
#  'total_records': 78,
#  'next_page_token': 'oQW59EPu83mo5ZKNo80U7Ee0foq8xEooUB2',
#  'participants': [{'id': 'qrOc8lYCRBOMK-5zb1WAXQ',
#    'name': 'Kyle Coapman',
#    'user_email': 'kcoapman@northstaracademy.org'},
#   {'id': 'pTH5rJmcT-S5tGNKCJOang',
#    'name': 'Nathan Campos',
#    'user_email': 'nathan.t.campos@student.northstaracademy.org'},
#   {'id': 'AMFBY-EfRhSmX40o1kzFCw',
#    'name': 'Bridrich Quartsin',
#    'user_email': 'bridrich.quartsin@student.northstaracademy.org'},
#   {'id': '12xyoI0HRm6Wz9aIoXTfyg',
#    'name': 'Sade Harvey',
#    'user_email': 'sade.a.harvey@student.northstaracademy.org'},
#   {'id': 'o5F1ADmkSNqbEWs1igHtVA',
#    'name': 'Angel Siguencia',
#    'user_email': 'angel.siguencia@student.northstaracademy.org'},
#   {'id': 'tixnamGLS0aWNVhNIUTPMA',
#    'name': 'Jenifer Tamay',
#    'user_email': 'jenifer.m.tamay@student.northstaracademy.org'},
#   {'id': '',
#    'name': 'Simone Smith',
#    'user_email': 'simone.mitchellsmith@student.northstaracademy.org'},
#   {'id': 'tixnamGLS0aWNVhNIUTPMA',
#    'name': 'Jenifer Tamay',
#    'user_email': 'jenifer.m.tamay@student.northstaracademy.org'},
#   {'id': 'WLR8-NV_QIOm-xlovyl7Yg',
#    'name': 'Jerelyn Norman',
#    'user_email': 'jerelyn.norman@student.northstaracademy.org'},
#   {'id': 'QyX_pVLuQoKRyh-sMG7z7w',
#    'name': 'Amanda Oppong',
#    'user_email': 'amanda.a.oppong@student.northstaracademy.org'},
#   {'id': '',
#    'name': 'Simone Smith',
#    'user_email': 'simone.mitchellsmith@student.northstaracademy.org'},
#   {'id': '5R5NReozRyibvrdFpY6sJA',
#    'name': 'Noah-Simone Blackwell',
#    'user_email': 'noahsimone.blackwell@student.northstaracademy.org'},
#   {'id': '2Ilw8EpSQaiS_T6U-OTzXg',
#    'name': 'Samijah Hill',
#    'user_email': 'samijah.k.hill@student.northstaracademy.org'},
#   {'id': '',
#    'name': 'Simone Smith',
#    'user_email': 'simone.mitchellsmith@student.northstaracademy.org'},
#   {'id': 'AMFBY-EfRhSmX40o1kzFCw',
#    'name': 'Bridrich Quartsin',
#    'user_email': 'bridrich.quartsin@student.northstaracademy.org'},
#   {'id': 'tixnamGLS0aWNVhNIUTPMA',
#    'name': 'Jenifer Tamay',
#    'user_email': 'jenifer.m.tamay@student.northstaracademy.org'},
#   {'id': 'WLR8-NV_QIOm-xlovyl7Yg',
#    'name': 'Jerelyn Norman',
#    'user_email': 'jerelyn.norman@student.northstaracademy.org'},
#   {'id': 'pTH5rJmcT-S5tGNKCJOang',
#    'name': 'Nathan Campos',
#    'user_email': 'nathan.t.campos@student.northstaracademy.org'},
#   {'id': 'QyX_pVLuQoKRyh-sMG7z7w',
#    'name': 'Amanda Oppong',
#    'user_email': 'amanda.a.oppong@student.northstaracademy.org'},
#   {'id': '12xyoI0HRm6Wz9aIoXTfyg',
#    'name': 'Sade Harvey',
#    'user_email': 'sade.a.harvey@student.northstaracademy.org'},
#   {'id': 'o5F1ADmkSNqbEWs1igHtVA',
#    'name': 'Angel Siguencia',
#    'user_email': 'angel.siguencia@student.northstaracademy.org'},
#   {'id': 'HKglnFn5Rk6So5ieExQc6Q',
#    'name': 'Saharah Harris',
#    'user_email': 'saharah.harris@student.northstaracademy.org'},
#   {'id': 'fDaHz1Y_QLaOMPhRcyIAgA',
#    'name': 'Beverly Gopre',
#    'user_email': 'beverly.a.gopre@student.northstaracademy.org'},
#   {'id': 'Xc1lb_68Tc2mFjZTed8dYA',
#    'name': "She'Mille Bryan",
#    'user_email': 'shemille.a.bryan@student.northstaracademy.org'},
#   {'id': 'fDaHz1Y_QLaOMPhRcyIAgA',
#    'name': 'Beverly Gopre',
#    'user_email': 'beverly.a.gopre@student.northstaracademy.org'},
#   {'id': 'qrOc8lYCRBOMK-5zb1WAXQ',
#    'name': 'Kyle Coapman',
#    'user_email': 'kcoapman@northstaracademy.org'},
#   {'id': 'qrOc8lYCRBOMK-5zb1WAXQ',
#    'name': 'Kyle Coapman',
#    'user_email': 'kcoapman@northstaracademy.org'},
#   {'id': 'Xc1lb_68Tc2mFjZTed8dYA',
#    'name': "She'Mille Bryan",
#    'user_email': 'shemille.a.bryan@student.northstaracademy.org'},
#   {'id': '5R5NReozRyibvrdFpY6sJA',
#    'name': 'Noah-Simone Blackwell',
#    'user_email': 'noahsimone.blackwell@student.northstaracademy.org'},
#   {'id': 'HKglnFn5Rk6So5ieExQc6Q',
#    'name': 'Saharah Harris',
#    'user_email': 'saharah.harris@student.northstaracademy.org'}]}
